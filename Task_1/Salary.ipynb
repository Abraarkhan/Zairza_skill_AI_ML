# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import seaborn as sns

# %%
salary_data = pd.read_csv( r'C:\Users\abrde\Desktop\Salary_Data.csv')
salary_data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.scatter(salary_data['YearsExperience'], salary_data['Salary'])

plt.xlabel('YearsExperience')
plt.ylabel('Salary')

plt.grid(True)

plt.style.use('fivethirtyeight')

plt.title('YearsExperience vs Salary')
# Out:
# Text(0.5, 1.0, 'YearsExperience vs Salary')

# %%
X = np.array(salary_data['YearsExperience'])
y = np.array(salary_data['Salary'])

# %%
X = X.reshape(-1,1)

# %%
linear = LinearRegression()

# %%
linear.fit(X,y)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([9449.96232146])

# %%
linear.intercept_
# Out:
# 25792.20019866871

# %%
linear.predict([[1.2]])
# Out:
# array([37132.15498441])

# %%
linear.score(X,y)
# Out:
# 0.9569566641435086

# %%
plt.figure(figsize = (10,6))

plt.scatter(salary_data['YearsExperience'], salary_data['Salary'], color = 'black', label = 'Datapoints')
plt.plot(salary_data['YearsExperience'], linear.predict(salary_data[['YearsExperience']]), color = 'blue', label = 'Linear regression')

plt.xlabel('YearsExperience')
plt.ylabel('Salary')

plt.title('Years of Experience vs Salary')

plt.grid(True)

plt.style.use('fivethirtyeight')

plt.legend()
